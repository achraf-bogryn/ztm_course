# %%
# Import matplotlib and setup the figures to display within the notebook
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
plt.plot();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1172576b821b> in <cell line: 1>()
# ----> 1 plt.plot();
#
# NameError: name 'plt' is not defined

# %%
plt.plot([1,2,3,4])

# %%
# Create some data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
# First Method
fig=plt.figure()#add figure
ax=fig.add_subplot()#add axis
ax.plot(x,y)#plot
plt.show()

# %%
# Second Method
fig=plt.figure()
ax=fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show();

# %%
# Third Method
fig,ax=plt.subplots()
ax.plot(x,y)

# %%
# Steps to plot figure

# 1 import  matplotlib library
# 2 - Prepare Data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
# 3 - Setup Plot
fig , ax = plt.subplots(figsize=(10,10))
# 4 - Plot Data
plt.plot(x,y)
# 5 - Customize Plot
ax.set(title='First Plot',xlabel='x',ylabel='y')
# 6 - Show and save
fig.savefig('../content/drive/MyDrive/ML_project/Fplot.png')

# %%
import numpy as np

# %%
x=np.random.rand(40)

# %%
fig , ax  = plt.subplots()
ax.scatter(x, x**2)

# %%
fig , ax  = plt.subplots()
ax.plot(x, np.exp(x));

# %%
fruit_price = {"banan":10,"apple":20,"orange":30}
fig ,ax = plt.subplots()
ax.bar(fruit_price.keys(),fruit_price.values())
ax.set(title='Fruit Price',xlabel='Fruit',ylabel='Price')
fig.savefig('../content/drive/MyDrive/ML_project/Bar')

# %%
# fig.ax = plt.subplots()
# ax.barh(list(fruit_price.keys()),list(fruit_price.values()));
# # ax.set(title='Fruit Price',xlabel='Price',ylabel='Fruit')
# plt.show()

fig, ax = plt.subplots()
ax.barh(list(fruit_price.keys()), list(fruit_price.values()))
ax.set(title='Fruit Price', xlabel='Price', ylabel='Fruit')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Hstogram
rand = np.random.rand(100)
fig , ax  = plt.subplots()
ax.hist(rand,bins=50)
ax.set(title='Histogram',xlabel='Value',ylabel='Frequency')
plt.show()

# %%
# Create Multiple in figure in same Figure

fig , (ax1 , ax2) = plt.subplots(nrows=1 ,ncols=2 , figsize=(10,5))
ax1.plot(x,x**2)
ax2.bar(fruit_price.keys(),fruit_price.values())
ax2.set(title='Fruit Price',xlabel='Fruit',ylabel='Price')
plt.plot()
# Out:
# []

# %%
fig , ax = plt.subplots(nrows=2 , ncols = 2 , figsize=(10,10))
ax[0,0].plot(x,x**2)
ax[0,1].bar(fruit_price.keys(),fruit_price.values())
ax[1,0].barh(list(fruit_price.keys()),list(fruit_price.values()))
ax[1,1].scatter(x,x**2)
fig.savefig('../content/drive/MyDrive/ML_project/Multiple.png')
plt.show()

# %%
import pandas as pd
# Work with Real Data By usin Pandas
car=pd.read_csv('/content/drive/MyDrive/ML_project/car-sales.csv')

# %%
car
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car['Price'] = car['Price'].str.replace('[\$\,.]', '', regex=True)
car
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car['Price'] = car['Price'].str[:-2]
car
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
# Add New column Date_Column
car['Sale_Date'] = pd.date_range(start='2023-01-01', periods=len(car))
car
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale_Date
# 0  Toyota  White         150043      4   4000 2023-01-01
# 1   Honda    Red          87899      4   5000 2023-01-02
# 2  Toyota   Blue          32549      3   7000 2023-01-03
# 3     BMW  Black          11179      5  22000 2023-01-04
# 4  Nissan  White         213095      4   3500 2023-01-05
# 5  Toyota  Green          99213      4   4500 2023-01-06
# 6   Honda   Blue          45698      4   7500 2023-01-07
# 7   Honda   Blue          54738      4   7000 2023-01-08
# 8  Toyota  White          60000      4   6250 2023-01-09
# 9  Nissan  White          31600      4   9700 2023-01-10

# %%
car['Total_Price'] = car['Price'].astype(int)
car
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale_Date  Total_Price
# 0  Toyota  White         150043      4   4000 2023-01-01         4000
# 1   Honda    Red          87899      4   5000 2023-01-02         5000
# 2  Toyota   Blue          32549      3   7000 2023-01-03         7000
# 3     BMW  Black          11179      5  22000 2023-01-04        22000
# 4  Nissan  White         213095      4   3500 2023-01-05         3500
# 5  Toyota  Green          99213      4   4500 2023-01-06         4500
# 6   Honda   Blue          45698      4   7500 2023-01-07         7500
# 7   Honda   Blue          54738      4   7000 2023-01-08         7000
# 8  Toyota  White          60000      4   6250 2023-01-09         6250
# 9  Nissan  White          31600      4   9700 2023-01-10         9700

# %%
# fig , zx  = plt.subplots()
car.plot(x='Sale_Date',y='Total_Price',kind='line');

# %%
car['Price']=car['Price'].astype(int)

# %%
car.dtypes
# Out:
# Make                     object
# Colour                   object
# Odometer (KM)             int64
# Doors                     int64
# Price                     int64
# Sale_Date        datetime64[ns]
# Total_Price               int64
# dtype: object

# %%
car.plot(x='Odometer (KM)', y = 'Price',kind='scatter');

# %%
df = np.random.rand(10,4)
dt=pd.DataFrame(df ,columns=['a','b','c','d'])

# %%
dt
# Out:
#           a         b         c         d
# 0  0.986454  0.295870  0.742180  0.212957
# 1  0.236010  0.066742  0.924645  0.513504
# 2  0.463373  0.048148  0.076456  0.673903
# 3  0.111003  0.917301  0.439437  0.855835
# 4  0.790861  0.374901  0.153377  0.425555
# 5  0.013073  0.495874  0.396822  0.677606
# 6  0.293928  0.108919  0.273067  0.301421
# 7  0.537490  0.635315  0.299359  0.698324
# 8  0.984579  0.309321  0.903186  0.815275
# 9  0.961163  0.930415  0.972644  0.742046

# %%
dt.plot(kind='bar');

# %%
car.plot(x='Make' , y='Odometer (KM)' , kind='barh');

# %%
car['Odometer (KM)'].plot.hist();

# %%
car['Odometer (KM)'].plot.hist(bins=40);

# %%
# Let's try with another dataset
heart_disease = pd.read_csv("/content/drive/MyDrive/ML_project/heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
heart_disease['age'].plot.hist(bins=50);

# %%
heart_disease.plot.hist(subplots=True,figsize=(10,30));

# %%
over_50 = heart_disease[heart_disease['age']>50]
over_50.head();
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
l=len(over_50);
l
# Out:
# 208

# %%
over_50.plot(kind='scatter',x='age',y='chol',c='thal');

# %%
fig , ax = plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",x='age',y='chol',c='target',ax=ax);
ax.set_xlim([40,100]);

# %%
# Make plot more fiffucult
fig , ax = plt.subplots(figsize=(10,6))
# Plot te data
scatter = ax.scatter(over_50["age"],
                     over_50["chol"],
                     c=over_50["target"])

# Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels",
        xlabel="Age",
       ylabel="cholesterol");

ax.legend(*scatter.legend_elements(), title="Target");

# %%
# Make plot more fiffucult
fig , ax = plt.subplots(figsize=(10,6))
# Plot te data
scatter = ax.scatter(over_50["age"],
                     over_50["chol"],
                     c=over_50["target"])

# Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels",
        xlabel="Age",
       ylabel="cholesterol");

ax.legend(*scatter.legend_elements(), title="Target");
# Add meanLine
ax.axhline(over_50["chol"].mean(),ls='--',color='red');
ax.axvline(over_50["age"].mean(),ls='--',color='red');

# %%
fig , ax = plt.subplots(nrows=2 , ncols=1, figsize=(10,8))

# Ad data for ax0
scatter = ax[0].scatter(over_50["age"],
                     over_50["chol"],
                     c=over_50["target"],
                        cmap="winter")
# Customize ax0
ax[0].set(title="Heart Disease and Cholesterol Levels",
        xlabel="Age",
       ylabel="cholesterol");

ax[0].legend(*scatter.legend_elements(), title="Target");

# Add meanLine ax0
ax[0].axhline(over_50["chol"].mean(),ls='--',color='red');

# Ad data for ax1
scatter = ax[1].scatter(over_50["age"],
                     over_50["thalach"],
                     c=over_50["target"])
# Customize ax1
ax[1].set(title="Heart Disease and Max Heart Rate",
        xlabel="Age",
       ylabel="Max Heart Rate");

ax[1].legend(*scatter.legend_elements(), title="Target");

# Add meanLine ax1
ax[1].axhline(over_50["thalach"].mean(),ls='--',color='red');

# Title the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');

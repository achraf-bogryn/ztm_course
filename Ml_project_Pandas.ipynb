# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
car_sales = pd.read_csv('/content/drive/MyDrive/ML_project/car-sales.csv')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales['Odometer (KM)'].mean()
# Out:
# 78601.4

# %%
#exporting data fram
car_sales.to_csv('/content/drive/MyDrive/ML_project/data_exported.csv',index=False)

# %%
data_exported = pd.read_csv('/content/drive/MyDrive/ML_project/data_exported.csv')

# %%
data_exported
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# describe data
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.count()
# Out:
# Make             10
# Colour           10
# Odometer (KM)    10
# Doors            10
# Price            10
# dtype: int64

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
  len(car_sales)
# Out:
# 10

# %% [markdown]
# # **Viewing and Selecting Data**

# %%
animals=pd.Series(["Cat","Dog","Bird","rabeet","Snake"],index=[1,3,5,1,3])

# %%
animals
# Out:
# 1       Cat
# 3       Dog
# 5      Bird
# 1    rabeet
# 3     Snake
# dtype: object

# %%
animals.loc[5]
# Out:
# 'Bird'

# %%
animals.loc[1]
# Out:
# 1       Cat
# 1    rabeet
# dtype: object

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 1       Cat
# 3       Dog
# 5      Bird
# 1    rabeet
# 3     Snake
# dtype: object

# %%
animals.iloc[0]
# Out:
# 'Cat'

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.Make
# car_sales['Make']
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales[car_sales.Colour=='White']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales[car_sales['Odometer (KM)']>45000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Compare Bewteen Two Column
pd.crosstab(car_sales["Make"],car_sales["Colour"])
# Out:
# Colour  Black  Blue  Green  Red  White
# Make
# BMW         1     0      0    0      0
# Honda       0     2      0    1      0
# Nissan      0     0      0    0      2
# Toyota      0     1      1    0      2

# %%
Numeric_Value = pd.DataFrame({'Doors':car_sales['Doors'],'Distance':car_sales['Odometer (KM)']})

# %%
Numeric_Value.groupby(["Doors"]).mean()
# Out:
#        Distance
# Doors
# 3      32549.00
# 4      92785.75
# 5      11179.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$,\.]', '', regex=True).astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %% [markdown]
# # ***Manipulating Data***

# %%
# Manipulating Data
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_sales_missing = pd.read_csv('/content/drive/MyDrive/ML_project/car-sales-missing-data.csv')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing_droped= car_sales_missing.dropna()

# %%
car_sales_missing_droped
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing_droped.to_csv('/content/drive/MyDrive/ML_project/car_sales_missing_droped.csv',index=False)

# %%
# add colmn to car_sales dataset using DataSeries
seats_columns=pd.Series([5,5,5,5,5])
car_sales["Seats"]=seats_columns

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    NaN
# 6   honda   Blue          45698      4   750000    NaN
# 7   honda   Blue          54738      4   700000    NaN
# 8  toyota  White          60000      4   625000    NaN
# 9  nissan  White          31600      4   970000    NaN

# %%
car_sales["Seats"].fillna(5,inplace=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    5.0
# 6   honda   Blue          45698      4   750000    5.0
# 7   honda   Blue          54738      4   700000    5.0
# 8  toyota  White          60000      4   625000    5.0
# 9  nissan  White          31600      4   970000    5.0

# %%
#Column use python list
fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 4.7, 7.6, 8.7, 3.0, 4.5]
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 8  toyota  White          60000      4   625000    5.0             3.0
# 9  nissan  White          31600      4   970000    5.0             4.5

# %%
car_sales["Total fuel used (L)"] = (car_sales["Odometer (KM)"]/100* car_sales["Fuel per 100KM"])
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 8  toyota  White          60000      4   625000    5.0             3.0
# 9  nissan  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)
# 0            11253.225
# 1             8086.708
# 2             1627.450
# 3             1073.184
# 4            18539.265
# 5             4663.011
# ...

# %%
#create clumn a single value
car_sales["Number of wheels"]=4

# %%
#add column a type boolean
car_sales["Passed road saftey"]=True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 8  toyota  White          60000      4   625000    5.0             3.0
# 9  nissan  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0            11253.225                 4                True
# 1             8086.708                 4                True
# ...

# %%
car_sales.dtypes
# Out:
# Make                    object
# Colour                  object
# Odometer (KM)            int64
# Doors                    int64
# Price                    int64
# Seats                  float64
# Fuel per 100KM         float64
# Total fuel used (L)    float64
# Number of wheels         int64
# Passed road saftey        bool
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 8  toyota  White          60000      4   625000    5.0             3.0
# 9  nissan  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0            11253.225                 4                True
# 1             8086.708                 4                True
# ...

# %%
# Sample car_sales
car_sales_sampled = car_sales.sample(frac=0.5)
car_sales_sampled
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per 100KM  \
# 2  toyota   Blue          32549      3  700000    5.0             5.0
# 7   honda   Blue          54738      4  700000    5.0             8.7
# 5  toyota  Green          99213      4  450000    5.0             4.7
# 0  toyota  White         150043      4  400000    5.0             7.5
# 4  nissan  White         213095      4  350000    5.0             8.7
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 2             1627.450                 4                True
# 7             4762.206                 4                True
# 5             4663.011                 4                True
# 0            11253.225                 4                True
# 4            18539.265                 4                True

# %%
car_sales_shuffeld=car_sales.sample(frac=1)
car_sales_shuffeld
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 8  toyota  White          60000      4   625000    5.0             3.0
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 0  toyota  White         150043      4   400000    5.0             7.5
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 4  nissan  White         213095      4   350000    5.0             8.7
# 9  nissan  White          31600      4   970000    5.0             4.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 3     bmw  Black          11179      5  2200000    5.0             9.6
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 8             1800.000                 4                True
# 6             3473.048                 4                True
# ...

# %%
# only if we want print 20% of Data
car_sales_shuffeld.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per 100KM  \
# 1   honda    Red          87899      4  500000    5.0             9.2
# 0  toyota  White         150043      4  400000    5.0             7.5
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 1             8086.708                 4                True
# 0            11253.225                 4                True

# %%
car_sales_shuffeld.reset_index(drop=True,inplace=True)
car_sales_shuffeld
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White          60000      4   625000    5.0             3.0
# 1   honda   Blue          45698      4   750000    5.0             7.6
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3  toyota  White         150043      4   400000    5.0             7.5
# 4  toyota  Green          99213      4   450000    5.0             4.7
# 5  nissan  White         213095      4   350000    5.0             8.7
# 6  nissan  White          31600      4   970000    5.0             4.5
# 7   honda    Red          87899      4   500000    5.0             9.2
# 8   honda   Blue          54738      4   700000    5.0             8.7
# 9     bmw  Black          11179      5  2200000    5.0             9.6
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0             1800.000                 4                True
# 1             3473.048                 4                True
# ...

# %%
car_sales_shuffeld_frac = car_sales_shuffeld.sample(frac=1)
car_sales_shuffeld_frac
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 9     bmw  Black          11179      5  2200000    5.0             9.6
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 7   honda    Red          87899      4   500000    5.0             9.2
# 6  nissan  White          31600      4   970000    5.0             4.5
# 0  toyota  White          60000      4   625000    5.0             3.0
# 8   honda   Blue          54738      4   700000    5.0             8.7
# 1   honda   Blue          45698      4   750000    5.0             7.6
# 3  toyota  White         150043      4   400000    5.0             7.5
# 5  nissan  White         213095      4   350000    5.0             8.7
# 4  toyota  Green          99213      4   450000    5.0             4.7
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 9             1073.184                 4                True
# 2             1627.450                 4                True
# ...

# %%
car_sales_shuffeld_frac.reset_index(inplace=True)
car_sales_shuffeld_frac
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0      9     bmw  Black          11179      5  2200000    5.0             9.6
# 1      2  toyota   Blue          32549      3   700000    5.0             5.0
# 2      7   honda    Red          87899      4   500000    5.0             9.2
# 3      6  nissan  White          31600      4   970000    5.0             4.5
# 4      0  toyota  White          60000      4   625000    5.0             3.0
# 5      8   honda   Blue          54738      4   700000    5.0             8.7
# 6      1   honda   Blue          45698      4   750000    5.0             7.6
# 7      3  toyota  White         150043      4   400000    5.0             7.5
# 8      5  nissan  White         213095      4   350000    5.0             8.7
# 9      4  toyota  Green          99213      4   450000    5.0             4.7
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# ...

# %%
car_sales_shuffeld_frac.drop("index",axis=1,inplace=True)

# %%
car_sales_shuffeld_frac
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0     bmw  Black          11179      5  2200000    5.0             9.6
# 1  toyota   Blue          32549      3   700000    5.0             5.0
# 2   honda    Red          87899      4   500000    5.0             9.2
# 3  nissan  White          31600      4   970000    5.0             4.5
# 4  toyota  White          60000      4   625000    5.0             3.0
# 5   honda   Blue          54738      4   700000    5.0             8.7
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7  toyota  White         150043      4   400000    5.0             7.5
# 8  nissan  White         213095      4   350000    5.0             8.7
# 9  toyota  Green          99213      4   450000    5.0             4.7
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0             1073.184                 4                True
# 1             1627.450                 4                True
# ...

# %%
car_sales_shuffeld_frac['Odometer (KM)'] =car_sales['Odometer (KM)'].apply(lambda x:x/1.6)

# %%
car_sales_shuffeld_frac.head(2)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0     bmw  Black      93776.875      5  2200000    5.0             9.6
# 1  toyota   Blue      54936.875      3   700000    5.0             5.0
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0             1073.184                 4                True
# 1             1627.450                 4                True

# %%
car_sales.head(2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4  400000    5.0             7.5
# 1   honda    Red          87899      4  500000    5.0             9.2
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0            11253.225                 4                True
# 1             8086.708                 4                True
